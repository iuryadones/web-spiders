# %%
import json
import pandas as pd

# %%
arquivo = open("dados_2017.json")
leitura = arquivo.read()
dados = json.loads(leitura)

# %%
frame_data = pd.DataFrame(dados)
frame_data
# Out:
#                                        _id  \
# 0     {'$oid': '5967fcff0f5366048956e7d6'}
# 1     {'$oid': '5967fd000f5366048956e7d7'}
# 2     {'$oid': '5967fd000f5366048956e7d8'}
# 3     {'$oid': '5967fd000f5366048956e7d9'}
# 4     {'$oid': '5967fd000f5366048956e7da'}
# 5     {'$oid': '5967fd000f5366048956e7db'}
# 6     {'$oid': '5967fd000f5366048956e7dc'}
# 7     {'$oid': '5967fd000f5366048956e7dd'}
# 8     {'$oid': '5967fd000f5366048956e7de'}
# 9     {'$oid': '5967fd000f5366048956e7df'}
# 10    {'$oid': '5967fd000f5366048956e7e0'}
# 11    {'$oid': '5967fd000f5366048956e7e1'}
# 12    {'$oid': '5967fd000f5366048956e7e2'}
# 13    {'$oid': '5967fd000f5366048956e7e3'}
# 14    {'$oid': '5967fd000f5366048956e7e4'}
# 15    {'$oid': '5967fd000f5366048956e7e5'}
# 16    {'$oid': '5967fd000f5366048956e7e6'}
# 17    {'$oid': '5967fd000f5366048956e7e7'}
# 18    {'$oid': '5967fd000f5366048956e7e8'}
# 19    {'$oid': '5967fd000f5366048956e7e9'}
# 20    {'$oid': '5967fd000f5366048956e7ea'}
# 21    {'$oid': '5967fd000f5366048956e7eb'}
# 22    {'$oid': '5967fd000f5366048956e7ec'}
# 23    {'$oid': '5967fd000f5366048956e7ed'}
# 24    {'$oid': '5967fd000f5366048956e7ee'}
# 25    {'$oid': '5967fd000f5366048956e7ef'}
# 26    {'$oid': '5967fd000f5366048956e7f0'}
# 27    {'$oid': '5967fd000f5366048956e7f1'}
# 28    {'$oid': '5967fd000f5366048956e7f2'}
# 29    {'$oid': '5967fd000f5366048956e7f3'}
# ...                                    ...
# 5542  {'$oid': '596811c60f5366048956fc69'}
# 5543  {'$oid': '596811c60f5366048956fc6a'}
# 5544  {'$oid': '596811c60f5366048956fc6b'}
# 5545  {'$oid': '596811c60f5366048956fc6c'}
# 5546  {'$oid': '596811c60f5366048956fc6d'}
# 5547  {'$oid': '596811c60f5366048956fc6e'}
# 5548  {'$oid': '596811c60f500b47d6ece973'}
# 5549  {'$oid': '596811c60f5366048956fc6f'}
# 5550  {'$oid': '596811c60f5366048956fc70'}
# 5551  {'$oid': '596811c60f5366048956fc71'}
# 5552  {'$oid': '596811c60f5366048956fc72'}
# 5553  {'$oid': '596811c60f5366048956fc73'}
# 5554  {'$oid': '596811c70f500b47d6ece992'}
# 5555  {'$oid': '596811cf0f500b47d6ece9d6'}
# 5556  {'$oid': '596811cf0f500b47d6ece9dc'}
# 5557  {'$oid': '596811cf0f5366048956fc74'}
# 5558  {'$oid': '596811cf0f5366048956fc75'}
# 5559  {'$oid': '596811cf0f5366048956fc76'}
# 5560  {'$oid': '596811cf0f5366048956fc77'}
# 5561  {'$oid': '596811cf0f5366048956fc78'}
# 5562  {'$oid': '596811cf0f5366048956fc79'}
# 5563  {'$oid': '596811cf0f5366048956fc7a'}
# 5564  {'$oid': '596811d90f5366048956fc7b'}
# 5565  {'$oid': '596811d90f5366048956fc7c'}
# 5566  {'$oid': '596811d90f5366048956fc7d'}
# 5567  {'$oid': '596811d90f500b47d6ecea66'}
# 5568  {'$oid': '596811d90f500b47d6ecea6c'}
# 5569  {'$oid': '596811d90f5366048956fc7e'}
# 5570  {'$oid': '596811d90f5366048956fc7f'}
# 5571  {'$oid': '596811d90f5366048956fc80'}
#
#                                                   acoes              estado  \
# 0     [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 1     [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 2     [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 3     [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 4     [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 5     [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 6     [{'funcoes': 'Saúde', 'acao_governamental': '8...  MATO GROSSO DO SUL
# 7     [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 8     [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 9     [{'funcoes': 'Assistência Social', 'acao_gover...  MATO GROSSO DO SUL
# 10    [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 11    [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 12    [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 13    [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 14    [{'funcoes': 'Educação', 'acao_governamental':...  MATO GROSSO DO SUL
# 15    [{'funcoes': 'Saúde', 'acao_governamental': '8...        MINAS GERAIS
# 16    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 17    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 18    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 19    [{'funcoes': 'Segurança Pública', 'acao_govern...        MINAS GERAIS
# 20    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 21    [{'funcoes': 'Saúde', 'acao_governamental': '8...        MINAS GERAIS
# 22    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 23    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 24    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 25    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 26    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 27    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 28    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# 29    [{'funcoes': 'Educação', 'acao_governamental':...        MINAS GERAIS
# ...                                                 ...                 ...
# 5542  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5543  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5544  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5545  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5546  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5547  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5548  [{'funcoes': 'Saúde', 'acao_governamental': '8...           TOCANTINS
# 5549  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5550  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5551  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5552  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5553  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5554  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5555  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5556  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5557  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5558  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5559  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5560  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5561  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5562  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5563  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5564  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5565  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5566  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5567  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5568  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5569  [{'funcoes': 'Saúde', 'acao_governamental': '8...           TOCANTINS
# 5570  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
# 5571  [{'funcoes': 'Educação', 'acao_governamental':...           TOCANTINS
#
#                      municipio
# 0                    BODOQUENA
# 1                   BELA VISTA
# 2                    BATAYPORA
# 3                   BATAGUASSU
# 4                 BANDEIRANTES
# 5                 ARAL MOREIRA
# 6                   AQUIDAUANA
# 7         APARECIDA DO TABOADO
# 8                 ANTONIO JOAO
# 9                     ANGELICA
# 10                ANAURILANDIA
# 11                   ANASTACIO
# 12                     AMAMBAI
# 13                 ALCINOPOLIS
# 14                  AGUA CLARA
# 15                ALEM PARAIBA
# 16                   ALBERTINA
# 17                      ALAGOA
# 18                    AIURUOCA
# 19                     AIMORES
# 20             AGUAS VERMELHAS
# 21              AGUAS FORMOSAS
# 22                     AGUANIL
# 23               AGUA COMPRIDA
# 24                    AGUA BOA
# 25                     ACUCENA
# 26                     ACAIACA
# 27                  ABRE CAMPO
# 28                      ABAETE
# 29         ABADIA DOS DOURADOS
# ...                        ...
# 5542          JAU DO TOCANTINS
# 5543      ITAPORA DO TOCANTINS
# 5544               ITAPIRATINS
# 5545                ITAGUATINS
# 5546                   ITACAJA
# 5547               PALMEIRANTE
# 5548                    PALMAS
# 5549        OLIVEIRA DE FATIMA
# 5550               NOVO JARDIM
# 5551               NOVO ALEGRE
# 5552               NOVO ACORDO
# 5553           NOVA ROSALANDIA
# 5554               NOVA OLINDA
# 5555                    NAZARE
# 5556                NATIVIDADE
# 5557              MURICILANDIA
# 5558  MONTE SANTO DO TOCANTINS
# 5559            MONTE DO CARMO
# 5560                 MIRANORTE
# 5561     MIRACEMA DO TOCANTINS
# 5562                   PIRAQUE
# 5563    PINDORAMA DO TOCANTINS
# 5564                PEQUIZEIRO
# 5565                     PEIXE
# 5566              PEDRO AFONSO
# 5567                PAU D'ARCO
# 5568                    PARANA
# 5569      PARAISO DO TOCANTINS
# 5570             PALMEIROPOLIS
# 5571    PALMEIRAS DO TOCANTINS
#
# [5572 rows x 4 columns]

# %%
acoes = {}
for i, municipio in enumerate(frame_data.municipio):
    acoes[municipio] = pd.DataFrame(frame_data.acoes[i])

# %%
acoes['RECIFE'].agg(['min','max'])
# Out:
#                                     acao_governamental             funcoes  \
# min  0045 - Fundo de Participação dos Municípios - ...  Assistência Social
# max  8948 - Apoio a Tecnologias Sociais de Acesso à...           Urbanismo
#
#      total_no_ano
# min  1.197000e+02
# max  1.699115e+08

# %%
acoes['RECIFE'].describe()
# Out:
#        total_no_ano
# count  4.800000e+01
# mean   1.212319e+07
# std    3.121352e+07
# min    1.197000e+02
# 25%    2.313832e+05
# 50%    9.449421e+05
# 75%    4.887081e+06
# max    1.699115e+08

# %%
acoes['RECIFE']
# Out:
#                                    acao_governamental                funcoes  \
# 0   8730 - Ampliação da Resolutividade da Saúde Bu...                  Saúde
# 1   00PI - Apoio à Alimentação Escolar na Educação...               Educação
# 2   1P95 - Apoio à Elaboração de Planos e Projetos...             Saneamento
# 3   8865 - Apoio à Execução de Projetos e Obras de...              Urbanismo
# 4        20R4 - Apoio à Implementação da Rede Cegonha                  Saúde
# 5      4525 - Apoio à Manutenção de Unidades de Saúde                  Saúde
# 6   8893 - Apoio à Organização, à Gestão e à Vigil...     Assistência Social
# 7   8948 - Apoio a Tecnologias Sociais de Acesso à...     Assistência Social
# 8   10S3 - Apoio à Urbanização de Assentamentos Pr...              Urbanismo
# 9   0969 - Apoio ao Transporte Escolar na Educação...               Educação
# 10  20YE - Aquisição e Distribuição de Imunobiológ...                  Saúde
# 11  8585 - Atenção à Saúde da População para Proce...                  Saúde
# 12  0E36 - Complementação da União ao Fundo de Man...               Educação
# 13  8761 - Custeio do Serviço de Atendimento Móvel...                  Saúde
# 14  20JP - Desenvolvimento de Atividades e Apoio a...       Desporto e Lazer
# 15  0547 - Transferências de Cotas-Partes da Compe...     Encargos Especiais
# 16  0551 - Transferências do Fundo Especial dos Ro...     Encargos Especiais
# 17  8719 - Vigilância Sanitária de Produtos, Servi...                  Saúde
# 18                 8577 - Piso de Atenção Básica Fixo                  Saúde
# 19  20AD - Piso de Atenção Básica Variável - Saúde...                  Saúde
# 20  20AE - Promoção da Assistência Farmacêutica e ...                  Saúde
# 21               20ZN - Promoção dos Direitos Humanos  Direitos da Cidadania
# 22  20YP - Promoção, Proteção e Recuperação da Saú...                  Saúde
# 23  0999 - Recursos para a Repartição da Contribui...     Encargos Especiais
# 24  8446 - Serviço de Apoio à Gestão Descentraliza...     Assistência Social
# 25          2A60 - Serviços de Proteção Social Básica     Assistência Social
# 26  2A69 - Serviços de Proteção Social Especial de...     Assistência Social
# 27  2A65 - Serviços de Proteção Social Especial de...     Assistência Social
# 28  099B - Transferência a Estados, Distrito Feder...     Encargos Especiais
# 29  0369 - Transferência da Cota-Parte do Salário-...     Encargos Especiais
# 30  00PX - Transferência de Recursos Arrecadados p...     Encargos Especiais
# 31  8442 - Transferência de Renda Diretamente às F...     Assistência Social
# 32  006M - Transferência do Imposto Territorial Rural     Encargos Especiais
# 33  217M - Desenvolvimento Integral na Primeira In...     Assistência Social
# 34  0515 - Dinheiro Direto na Escola para a Educaç...               Educação
# 35  8581 - Estruturação da Rede de Serviços de Ate...                  Saúde
# 36  8535 - Estruturação de Unidades de Atenção Esp...                  Saúde
# 37  2113 - Fomento à Pesquisa e à Inovação Tecnoló...   Ciência e Tecnologia
# 38  20I4 - Fomento a Pesquisa e Desenvolvimento em...   Ciência e Tecnologia
# 39  2095 - Fomento a Projetos de Implantação, Recu...   Ciência e Tecnologia
# 40  4156 - Fomento a Projetos Institucionais para ...   Ciência e Tecnologia
# 41  20YJ - Fortalecimento do Sistema Nacional de V...                  Saúde
# 42  0C33 - Fundo de Manutenção e Desenvolvimento d...     Encargos Especiais
# 43  0045 - Fundo de Participação dos Municípios - ...     Encargos Especiais
# 44  20AL - Incentivo Financeiro aos Estados, Distr...                  Saúde
# 45  20AB - Incentivo Financeiro aos Estados, Distr...                  Saúde
# 46  20AC - Incentivo Financeiro às ações de vigilâ...                  Saúde
# 47  20YR - Manutenção e Funcionamento do Programa ...                  Saúde
#
#     total_no_ano
# 0   4.279000e+05
# 1   2.852957e+06
# 2   2.695352e+05
# 3   1.109911e+06
# 4   8.059500e+04
# 5   3.000000e+05
# 6   1.061910e+05
# 7   1.161582e+07
# 8   4.480084e+06
# 9   1.197000e+02
# 10  2.772120e+05
# 11  1.075553e+08
# 12  1.602387e+07
# 13  4.799418e+06
# 14  1.200240e+06
# 15  1.692231e+05
# 16  2.334838e+06
# 17  3.014514e+04
# 18  1.490246e+07
# 19  2.536328e+07
# 20  3.318525e+06
# 21  2.670000e+05
# 22  6.692762e+07
# 23  1.013209e+06
# 24  1.648874e+06
# 25  8.766750e+05
# 26  3.840000e+05
# 27  1.362294e+06
# 28  5.473958e+05
# 29  6.528910e+06
# 30  9.122184e+06
# 31  6.541028e+07
# 32  4.561400e+02
# 33  1.500000e+05
# 34  1.343920e+05
# 35  3.961770e+05
# 36  3.966033e+06
# 37  2.373150e+05
# 38  3.600000e+05
# 39  3.332663e+06
# 40  1.359524e+05
# 41  5.900000e+04
# 42  4.621206e+07
# 43  1.699115e+08
# 44  5.150071e+06
# 45  2.135881e+05
# 46  2.976680e+05
# 47  5.000000e+04
